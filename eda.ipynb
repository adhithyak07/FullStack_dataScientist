# %% [markdown]
# import pandas

# %%
import pandas as pd
data = pd.read_csv("loan_approved.csv")

# %%
print(data["Loan_ID"])
# Out:
# 0      LP001002
# 1      LP001003
# 2      LP001005
# 3      LP001006
# 4      LP001008
#          ...
# 609    LP002978
# 610    LP002979
# 611    LP002983
# 612    LP002984
# 613    LP002990
# Name: Loan_ID, Length: 614, dtype: object

# %% [markdown]
# Loan_ID is nominal it is categorical and doesnt have any order

# %%
print(data["Gender"])
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#         ...
# 609    Female
# 610      Male
# 611      Male
# 612      Male
# 613    Female
# Name: Gender, Length: 614, dtype: object

# %% [markdown]
# Gender column belongs to nominal due to not having any order

# %%
print(data["Married"])
# Out:
# 0       No
# 1      Yes
# 2      Yes
# 3      Yes
# 4       No
#       ...
# 609     No
# 610    Yes
# 611    Yes
# 612    Yes
# 613     No
# Name: Married, Length: 614, dtype: object

# %% [markdown]
# Married column belongs to nominal due to not having any order

# %%
print(data["Dependents"])
# Out:
# 0       0
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 609     0
# 610    3+
# 611     1
# 612     2
# 613     0
# Name: Dependents, Length: 614, dtype: object

# %% [markdown]
# Dependents belongs to ordinal because of increasing order

# %%
print(data["Education"])
# Out:
# 0          Graduate
# 1          Graduate
# 2          Graduate
# 3      Not Graduate
# 4          Graduate
#            ...
# 609        Graduate
# 610        Graduate
# 611        Graduate
# 612        Graduate
# 613        Graduate
# Name: Education, Length: 614, dtype: object

# %% [markdown]
# Education column belongs to nominal due to not having any order

# %%
print(data["Self_Employed"])
# Out:
# 0       No
# 1       No
# 2      Yes
# 3       No
# 4       No
#       ...
# 609     No
# 610     No
# 611     No
# 612     No
# 613    Yes
# Name: Self_Employed, Length: 614, dtype: object

# %% [markdown]
# Gender column belongs to nominal due to not having any order

# %%
print(data["ApplicantIncome"])
# Out:
# 0      5849
# 1      4583
# 2      3000
# 3      2583
# 4      6000
#        ...
# 609    2900
# 610    4106
# 611    8072
# 612    7583
# 613    4583
# Name: ApplicantIncome, Length: 614, dtype: int64

# %% [markdown]
# ApplicantIncome is discrete because income is recorded as whole numeric counts.
#
# CoapplicantIncome is discrete because it represents integer income values.
#
# LoanAmount is discrete because loan amounts are stored as whole numbers.
#
# Loan_Amount_Term is discrete because it counts the number of months in whole units.
#
# Credit_History is ordinal because 0 and 1 show increasing credit reliability.
#
# Property_Area is nominal because Urban/Rural/Semiurban are labels with no order.
#
# Loan_Status is nominal because Y/N are just categories without ranking.

# %%
data["Loan_Amount_Term"].unique()
# Out:
# array([360., 120., 240.,  nan, 180.,  60., 300., 480.,  36.,  84.,  12.])

# %%
data["Gender"] = data["Gender"].fillna(data["Gender"].mode()[0])

# %%
data["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
data["Married"].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
data["Married"]=data["Married"].fillna(data["Married"].mode()[0])

# %%
print(data)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
mean=data["ApplicantIncome"].mean()
std=data["ApplicantIncome"].std()

# %%
head1=data["ApplicantIncome"].head()

# %%
for h in head1:
    z=(h-mean)/std
    print(z)
# Out:
# 0.07293135984867923
# -0.13430245319192854
# -0.3934265653904136
# -0.4616860440933626
# 0.09764882096173749

# %%
print(data["ApplicantIncome"].max())

print(data["ApplicantIncome"].min())


print(data["ApplicantIncome"].max()-data["ApplicantIncome"].min())
# Out:
# 81000
# 150
# 80850

# %%
print(data["ApplicantIncome"].skew())
print(data["CoapplicantIncome"].skew())
print(data["LoanAmount"].skew())
print(data["Loan_Amount_Term"].skew())
# Out:
# 6.539513113994625
# 7.491531216657306
# 2.677551679256059
# -2.362414124216269

# %%
print(data["ApplicantIncome"].kurt())
print(data["CoapplicantIncome"].kurt())
print(data["LoanAmount"].kurt())
print(data["Loan_Amount_Term"].kurt())
# Out:
# 60.54067593369113
# 84.95638421103374
# 10.40153349029416
# 6.673473692814259
